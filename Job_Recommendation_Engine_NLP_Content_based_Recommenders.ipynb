# %% [markdown]
# <a href="https://colab.research.google.com/github/SanthanaBharathiM/IBM-Project-22604-1659854912/blob/main/Job_Recommendation_Engine_NLP_Content_based_Recommenders.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd /content/drive/MyDrive/Recommendation/
# Out:
# /content/drive/MyDrive/Recommendation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import nltk
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.corpus import stopwords
import re
import string
from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.neighbors import NearestNeighbors

# %%
comb_jobs = pd.read_csv('data/Combined_Jobs_Final.csv')
experience = pd.read_csv('data/Experience.csv')
job_views = pd.read_csv('data/Job_Views.csv')
pos_int = pd.read_csv('data/Positions_Of_Interest.csv')
job_data = pd.read_csv('data/job_data.csv')

# %%
comb_jobs.head(3)
# Out:
#    Job.ID  Provider Status                                               Slug  \
# 0     111         1   open                    palo-alto-ca-tacolicious-server
# 1     113         1   open    san-francisco-ca-claude-lane-kitchen-staff-chef
# 2     117         1   open  san-francisco-ca-machka-restaurants-corp-barte...
#
#                                   Title            Position  \
# 0                  Server @ Tacolicious              Server
# 1      Kitchen Staff/Chef @ Claude Lane  Kitchen Staff/Chef
# 2  Bartender @ Machka Restaurants Corp.           Bartender
#
#                     Company           City  State.Name State.Code  ...  \
# 0               Tacolicious      Palo Alto  California         CA  ...
# 1               Claude Lane  San Francisco  California         CA  ...
# 2  Machka Restaurants Corp.  San Francisco  California         CA  ...
#
#              Industry                                    Job.Description  \
# 0  Food and Beverages  Tacolicious' first Palo Alto store just opened...
# 1  Food and Beverages   \r\n\r\nNew French Brasserie in S.F. Financia...
# 2  Food and Beverages  We are a popular Mediterranean wine bar and re...
#
#    Requirements Salary Listing.Start  Listing.End  Employment.Type  \
# 0           NaN    8.0           NaN          NaN        Part-Time
# 1           NaN    0.0           NaN          NaN        Part-Time
# 2           NaN   11.0           NaN          NaN        Part-Time
#
#   Education.Required               Created.At               Updated.At
# 0                NaN  2013-03-12 02:08:28 UTC  2014-08-16 15:35:36 UTC
# 1                NaN  2013-04-12 08:36:36 UTC  2014-08-16 15:35:36 UTC
# 2                NaN  2013-07-16 09:34:10 UTC  2014-08-16 15:35:37 UTC
#
# [3 rows x 23 columns]

# %%
experience.head(3)
# Out:
#    Applicant.ID                                      Position.Name  \
# 0         10001  Account Manager / Sales Administration / Quali...
# 1         10001    Electronics Technician / Item Master Controller
# 2         10001                                   Machine Operator
#
#         Employer.Name        City  State.Name State.Code  Start.Date  \
# 0  Barcode Resourcing  Bellingham  Washington         WA  2012-10-15
# 1         Ryzex Group  Bellingham  Washington         WA  2001-12-01
# 2         comptec inc      Custer  Washington         WA  1997-01-01
#
#      End.Date Job.Description  Salary Can.Contact.Employer  \
# 0         NaN             NaN     NaN                  NaN
# 1  2012-04-01             NaN     NaN                  NaN
# 2  1999-01-01             NaN     NaN                  NaN
#
#                 Created.At               Updated.At
# 0  2014-12-12 20:10:02 UTC  2014-12-12 20:10:02 UTC
# 1  2014-12-12 20:10:02 UTC  2014-12-12 20:10:02 UTC
# 2  2014-12-12 20:10:02 UTC  2014-12-12 20:10:02 UTC

# %%
job_data.head(3)
# Out:
#    Unnamed: 0  Job.ID                                               text
# 0           0     111  server tacolici palo alto part time tacolici f...
# 1           1     113  kitchen staff chef claud lane san francisco pa...
# 2           2     117  bartend machka restaur corp. san francisco par...

# %%
pos_int.head(3)
# Out:
#    Applicant.ID Position.Of.Interest               Created.At  \
# 0         10003     security officer  2014-12-12 21:20:54 UTC
# 1         10007               Server  2014-08-14 15:56:42 UTC
# 2         10007            Bartender  2014-08-14 15:56:44 UTC
#
#                 Updated.At
# 0  2014-12-12 21:20:54 UTC
# 1  2015-02-26 20:35:12 UTC
# 2  2015-02-19 23:21:28 UTC

# %%
job_data.head(3)
# Out:
#    Unnamed: 0  Job.ID                                               text
# 0           0     111  server tacolici palo alto part time tacolici f...
# 1           1     113  kitchen staff chef claud lane san francisco pa...
# 2           2     117  bartend machka restaur corp. san francisco par...

# %% [markdown]
# ### **Exploratory Data Analysis**

# %%
comb_jobs.isna().sum()
# Out:
# Job.ID                    0
# Provider                  0
# Status                    0
# Slug                      0
# Title                     0
# Position                  0
# Company                2271
# City                    135
# State.Name              171
# State.Code              171
# Address               84054
# Latitude                  0
# Longitude                 0
# Industry              83823
# Job.Description          56
# Requirements          84090
# Salary                83861
# Listing.Start           683
# Listing.End             167
# Employment.Type          10
# Education.Required      267
# Created.At                0
# Updated.At                0
# dtype: int64

# %% [markdown]
# There are a lot of missing values so I shall just selecct the columns for the jobs corpus. There are 23 columns, however for this dataframe I shall only use the Job.ID, Title, Position, Company, City and Job_Description, after which I shall preprocess.
# For the preprocessing step, I  shall
# - impute the missing values if any.
# - remove stop words.
# - remove not alphanumeric characters.
# - lemmatize the columns.
# -  merge all the columns in order to create a corpus of text for each job.

# %%
comb_jobs_df = comb_jobs[['Job.ID', 'Title', 'Position', 'Company', 'City', 'Employment.Type', 'Job.Description']]
comb_jobs_df.head()
# Out:
#    Job.ID                                        Title            Position  \
# 0     111                         Server @ Tacolicious              Server
# 1     113             Kitchen Staff/Chef @ Claude Lane  Kitchen Staff/Chef
# 2     117         Bartender @ Machka Restaurants Corp.           Bartender
# 3     121                      Server @ Teriyaki House              Server
# 4     127  Kitchen Staff/Chef @ Rosa Mexicano - Sunset  Kitchen Staff/Chef
#
#                     Company           City Employment.Type  \
# 0               Tacolicious      Palo Alto       Part-Time
# 1               Claude Lane  San Francisco       Part-Time
# 2  Machka Restaurants Corp.  San Francisco       Part-Time
# 3            Teriyaki House       Brisbane       Part-Time
# 4    Rosa Mexicano - Sunset    Los Angeles       Part-Time
#
#                                      Job.Description
# 0  Tacolicious' first Palo Alto store just opened...
# 1   \r\n\r\nNew French Brasserie in S.F. Financia...
# 2  We are a popular Mediterranean wine bar and re...
# 3   ● Serve food/drinks to customers in a profess...
# 4  Located at the heart of Hollywood, we are one ...

# %%
comb_jobs_df.isna().sum()
# Out:
# Job.ID                0
# Title                 0
# Position              0
# Company            2271
# City                135
# Employment.Type      10
# Job.Description      56
# dtype: int64

# %%
print(comb_jobs_df[pd.isnull(comb_jobs_df['City'])].shape)
df1 = comb_jobs_df[pd.isnull(comb_jobs_df['City'])]
print(df1[df1['City'] != np.nan]['Company'].unique())
df1.head()
# Out:
# (135, 7)
# ['St. Francis Hospital' 'CHI Payment Systems' 'Genesis Health Systems'
#  'Driveline Retail' 'Volvo Group' 'Home Instead Senior Care'
#  'Genesis Health System' 'Academic Year In America'
#  'Educational Testing Services' 'CBS Healthcare Services and Staffing']
#       Job.ID                                              Title  \
# 3425  142044       Registered Nurse (RN) @ St. Francis Hospital
# 3433  142054  Sales Representative - Business Development Op...
# 3434  142055       New Business Executive @ CHI Payment Systems
# 3435  142056  Outside Sales Representative (Business Develop...
# 3436  142057  Outside Sales Representative @ CHI Payment Sys...
#
#                                                Position               Company  \
# 3425                              Registered Nurse (RN)  St. Francis Hospital
# 3433  Sales Representative - Business Development Op...   CHI Payment Systems
# 3434                             New Business Executive   CHI Payment Systems
# 3435  Outside Sales Representative (Business Develop...   CHI Payment Systems
# 3436                       Outside Sales Representative   CHI Payment Systems
#
#      City      Employment.Type  \
# 3425  NaN  Full-Time/Part-Time
# 3433  NaN  Full-Time/Part-Time
# 3434  NaN  Full-Time/Part-Time
# 3435  NaN  Full-Time/Part-Time
# 3436  NaN  Full-Time/Part-Time
#
#                                         Job.Description
# 3425  Under the direction of the Clinical Coordinato...
# 3433  If you&rsquo;re energetic, motivated, hardwork...
# 3434  If you&rsquo;re energetic, motivated, hardwork...
# 3435  If you&rsquo;re energetic, motivated, hardwork...
# 3436  If you&rsquo;re energetic, motivated, hardwork...

# %% [markdown]
# There are 9 companies where the value for which the cities are missing. I did a little research on Google and imputed these values.

# %%
comb_jobs_df.loc[comb_jobs_df.Company == 'CHI Payment Systems', 'City'] = 'Williamsport'
comb_jobs_df.loc[comb_jobs_df.Company == 'Academic Year In America', 'City'] = 'Stamford'
comb_jobs_df.loc[comb_jobs_df.Company == 'CBS Healthcare Services and Staffing ', 'City'] = 'Urbandale'
comb_jobs_df.loc[comb_jobs_df.Company == 'Driveline Retail', 'City'] = 'Coppell'
comb_jobs_df.loc[comb_jobs_df.Company == 'Educational Testing Services', 'City'] = 'Jersey City'
comb_jobs_df.loc[comb_jobs_df.Company == 'Genesis Health System', 'City'] = 'Davenport'
comb_jobs_df.loc[comb_jobs_df.Company == 'Home Instead Senior Care', 'City'] = 'New Albany'
comb_jobs_df.loc[comb_jobs_df.Company == 'St. Francis Hospital', 'City'] = 'Litchfield'
comb_jobs_df.loc[comb_jobs_df.Company == 'Volvo Group', 'City'] = 'Greensboro'
comb_jobs_df.loc[comb_jobs_df.Company == 'CBS Healthcare Services and Staffing', 'City'] = 'Urbandale'
comb_jobs_df['Company'] = comb_jobs_df['Company'].replace(['Genesis Health Systems'], 'Genesis Health System')
# Out:
# <ipython-input-17-862eca733383>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comb_jobs_df['Company'] = comb_jobs_df['Company'].replace(['Genesis Health Systems'], 'Genesis Health System')

# %%
comb_jobs_df.isna().sum()
# Out:
# Job.ID                0
# Title                 0
# Position              0
# Company            2271
# City                  2
# Employment.Type      10
# Job.Description      56
# dtype: int64

# %%
df2 = comb_jobs_df[pd.isnull(comb_jobs_df['Employment.Type'])]
comb_jobs_df = comb_jobs_df.dropna(subset = ['Employment.Type'], axis = 0)

# %%
comb_jobs_df['Employment.Type'].unique()
# Out:
# array(['Part-Time', 'Full-Time/Part-Time', 'Seasonal/Temp', 'Per Diem',
#        'Intern', 'Full-Time', 'Contract', 'Temporary/seasonal'],
#       dtype=object)

# %%
#replacing na values with part time/full time
df2['Employment.Type'] = df2['Employment.Type'].fillna('Full-Time/Part-Time')
comb_jobs_df.groupby(['Employment.Type'])['Company'].count()
df2
# Out:
# <ipython-input-21-98588f515769>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Employment.Type'] = df2['Employment.Type'].fillna('Full-Time/Part-Time')
#        Job.ID                   Title         Position Company           City  \
# 10768  153197  Driving Partner @ Uber  Driving Partner    Uber  San Francisco
# 10769  153198  Driving Partner @ Uber  Driving Partner    Uber    Los Angeles
# 10770  153199  Driving Partner @ Uber  Driving Partner    Uber        Chicago
# 10771  153200  Driving Partner @ Uber  Driving Partner    Uber         Boston
# 10772  153201  Driving Partner @ Uber  Driving Partner    Uber      Ann Arbor
# 10773  153202  Driving Partner @ Uber  Driving Partner    Uber       Oklahoma
# 10774  153203  Driving Partner @ Uber  Driving Partner    Uber          Omaha
# 10775  153204  Driving Partner @ Uber  Driving Partner    Uber        Lincoln
# 10776  153205  Driving Partner @ Uber  Driving Partner    Uber    Minneapolis
# 10777  153206  Driving Partner @ Uber  Driving Partner    Uber       St. Paul
#
#            Employment.Type                                    Job.Description
# 10768  Full-Time/Part-Time  Uber is changing the way the world moves. From...
# 10769  Full-Time/Part-Time  Uber is changing the way the world moves. From...
# 10770  Full-Time/Part-Time  Uber is changing the way the world moves. From...
# 10771  Full-Time/Part-Time  Uber is changing the way the world moves. From...
# 10772  Full-Time/Part-Time  Uber is changing the way the world moves. From...
# 10773  Full-Time/Part-Time  Uber is changing the way the world moves. From...
# 10774  Full-Time/Part-Time  Uber is changing the way the world moves. From...
# 10775  Full-Time/Part-Time  Uber is changing the way the world moves. From...
# 10776  Full-Time/Part-Time  Uber is changing the way the world moves. From...
# 10777  Full-Time/Part-Time  Uber is changing the way the world moves. From...

# %%
comb_jobs_df = pd.concat([comb_jobs_df.iloc[:10768], df2, comb_jobs_df.iloc[10768:]], axis = 0).reset_index(drop = True)

# %%
comb_jobs_df.isna().sum()
# Out:
# Job.ID                0
# Title                 0
# Position              0
# Company            2271
# City                  2
# Employment.Type       0
# Job.Description      56
# dtype: int64

# %% [markdown]
# ##### **Creating the Jobs corpus**

# %% [markdown]
# To create the jobs corpora, I shall add the Position, Company, City, Employment.Type and Position columns

# %%
comb_jobs_df['Text'] = comb_jobs_df['Position'].map(str) + ' ' + comb_jobs_df['Company'] + ' ' + comb_jobs_df['City'] + ' ' + comb_jobs_df['Employment.Type'] + ' ' + comb_jobs_df['Job.Description'] + ' ' + comb_jobs_df['Title']
comb_jobs_df.head(2)
# Out:
#    Job.ID                             Title            Position      Company  \
# 0     111              Server @ Tacolicious              Server  Tacolicious
# 1     113  Kitchen Staff/Chef @ Claude Lane  Kitchen Staff/Chef  Claude Lane
#
#             City Employment.Type  \
# 0      Palo Alto       Part-Time
# 1  San Francisco       Part-Time
#
#                                      Job.Description  \
# 0  Tacolicious' first Palo Alto store just opened...
# 1   \r\n\r\nNew French Brasserie in S.F. Financia...
#
#                                                 Text
# 0  Server Tacolicious Palo Alto Part-Time Tacolic...
# 1  Kitchen Staff/Chef Claude Lane San Francisco P...

# %%
comb_jobs_all = comb_jobs_df[['Job.ID', 'Text', 'Title']]
comb_jobs_all = comb_jobs_all.fillna(' ')
comb_jobs_all.head()
# Out:
#    Job.ID                                               Text  \
# 0     111  Server Tacolicious Palo Alto Part-Time Tacolic...
# 1     113  Kitchen Staff/Chef Claude Lane San Francisco P...
# 2     117  Bartender Machka Restaurants Corp. San Francis...
# 3     121  Server Teriyaki House Brisbane Part-Time  ● Se...
# 4     127  Kitchen Staff/Chef Rosa Mexicano - Sunset Los ...
#
#                                          Title
# 0                         Server @ Tacolicious
# 1             Kitchen Staff/Chef @ Claude Lane
# 2         Bartender @ Machka Restaurants Corp.
# 3                      Server @ Teriyaki House
# 4  Kitchen Staff/Chef @ Rosa Mexicano - Sunset

# %%
comb_jobs_all.shape
# Out:
# (84090, 3)

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
stopword = stopwords.words('english')
stopword_ = set(stopwords.words('english'))
wn = WordNetLemmatizer()

# %%
# Create word tokens
def token_txt(token):
    return token not in stopword_ and token not in list(string.punctuation) and len(token) > 2

def clean_txt(text):
  clean_text = []
  clean_text2 = []
  text = re.sub("'", "", text)
  text = re.sub("(\\d|\\W)+", " ", text)
  text = text.replace("nbsp", "")
  clean_text = [wn.lemmatize(word, pos = "v") for word in word_tokenize(text.lower()) if token_txt(word)]
  clean_text2 = [word for word in clean_text if token_txt(word)]
  return " ".join(clean_text2)

# %%
comb_jobs_all['Text'] = comb_jobs_all['Text'].apply(clean_txt)

# %%
comb_jobs_all.tail()
# Out:
#        Job.ID                                               Text  \
# 84085      82  book keeper national japanese american histori...
# 84086      83  kitchen staff chef emporio rulli larkspur part...
# 84087      84  driver onigilly san francisco part time onigil...
# 84088      88  line cook machka restaurants corp san francisc...
# 84089      92  cashier kazoo restaurant san jose part time lo...
#
#                                                    Title
# 84085  Book Keeper @ National Japanese American Histo...
# 84086                 Kitchen Staff/Chef @ Emporio Rulli
# 84087                                  Driver @ Onigilly
# 84088               Line Cook @ Machka Restaurants Corp.
# 84089                         Cashier @ Kazoo Restaurant

# %% [markdown]
# #### **Term Ferquency - Inverse Document Frequency**

# %%
tfidf_vect = TfidfVectorizer()

# Fitting and transforming the vector
tfidf_comb = tfidf_vect.fit_transform((comb_jobs_all['Text']))
tfidf_comb
# Out:
# <84090x50753 sparse matrix of type '<class 'numpy.float64'>'
# 	with 8264225 stored elements in Compressed Sparse Row format>

# %% [markdown]
# #### **Creating the User Corpus**

# %%
job_views.head(3)
# Out:
#    Applicant.ID  Job.ID                                              Title  \
# 0         10000   73666              Cashiers & Valets Needed! @ WallyPark
# 1         10000   96655  Macy's Seasonal Retail Fragrance Cashier  - Ga...
# 2         10001   84141  Part Time Showroom Sales / Cashier @ Grizzly I...
#
#                                             Position                  Company  \
# 0                          Cashiers & Valets Needed!                WallyPark
# 1  Macy's Seasonal Retail Fragrance Cashier  - Ga...                   Macy's
# 2                 Part Time Showroom Sales / Cashier  Grizzly Industrial Inc.
#
#           City  State.Name State.Code Industry               View.Start  \
# 0       Newark  New Jersey         NJ      NaN  2014-12-12 20:12:35 UTC
# 1  Garden City    New York         NY      NaN  2014-12-12 20:08:50 UTC
# 2   Bellingham  Washington         WA      NaN  2014-12-12 20:12:32 UTC
#
#                   View.End  View.Duration               Created.At  \
# 0  2014-12-12 20:31:24 UTC         1129.0  2014-12-12 20:12:35 UTC
# 1  2014-12-12 20:10:15 UTC           84.0  2014-12-12 20:08:50 UTC
# 2  2014-12-12 20:17:18 UTC          286.0  2014-12-12 20:12:32 UTC
#
#                 Updated.At
# 0  2014-12-12 20:12:35 UTC
# 1  2014-12-12 20:08:50 UTC
# 2  2014-12-12 20:12:32 UTC

# %% [markdown]
# To create the user corpus, we shall use the Applicant.ID, Job.ID, Position, Company, City columns

# %%
job_view_df = job_views[['Applicant.ID', 'Job.ID', 'Position', 'Company', 'City']]
job_view_df['job_view_text'] = job_view_df['Position'].map(str) + "  " + job_view_df['Company'] + "  " + job_view_df['City']
job_view_df['job_view_text'] = job_view_df['job_view_text'].map(str).apply(clean_txt)
job_view_df['job_view_text'] = job_view_df['job_view_text'].str.lower()
job_view_df = job_view_df[['Applicant.ID', 'job_view_text']]
job_view_df.head()
# Out:
# <ipython-input-34-d5ff42057cfa>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   job_view_df['job_view_text'] = job_view_df['Position'].map(str) + "  " + job_view_df['Company'] + "  " + job_view_df['City']
# <ipython-input-34-d5ff42057cfa>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   job_view_df['job_view_text'] = job_view_df['job_view_text'].map(str).apply(clean_txt)
# <ipython-input-34-d5ff42057cfa>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   job_view_df['job_view_text'] = job_view_df['job_view_text'].str.lower()
#    Applicant.ID                                      job_view_text
# 0         10000                cashier valet need wallypark newark
# 1         10000  macys seasonal retail fragrance cashier garden...
# 2         10001  part time showroom sales cashier grizzly indus...
# 3         10002  event specialist part time advantage sales mar...
# 4         10002   bonefish kitchen staff bonefish grill greenville

# %% [markdown]
# #### Cleaning the Experience data

# %%
experience.head()
# Out:
#    Applicant.ID                                      Position.Name  \
# 0         10001  Account Manager / Sales Administration / Quali...
# 1         10001    Electronics Technician / Item Master Controller
# 2         10001                                   Machine Operator
# 3         10003                             maintenance technician
# 4         10003                                 Electrical Helper
#
#                Employer.Name         City            State.Name State.Code  \
# 0         Barcode Resourcing   Bellingham            Washington         WA
# 1                Ryzex Group   Bellingham            Washington         WA
# 2                comptec inc       Custer            Washington         WA
# 3           Winn residental    washington  District of Columbia         DC
# 4  michael and son services   alexandria               Virginia         VA
#
#    Start.Date    End.Date                                    Job.Description  \
# 0  2012-10-15         NaN                                                NaN
# 1  2001-12-01  2012-04-01                                                NaN
# 2  1997-01-01  1999-01-01                                                NaN
# 3         NaN         NaN  Necessary maintenance for "Make Ready" Plumbin...
# 4         NaN         NaN    repair and services of electrical construction
#
#    Salary Can.Contact.Employer               Created.At  \
# 0     NaN                  NaN  2014-12-12 20:10:02 UTC
# 1     NaN                  NaN  2014-12-12 20:10:02 UTC
# 2     NaN                  NaN  2014-12-12 20:10:02 UTC
# 3    10.0                False  2014-12-12 21:27:05 UTC
# 4     NaN                False  2014-12-12 21:27:05 UTC
#
#                 Updated.At
# 0  2014-12-12 20:10:02 UTC
# 1  2014-12-12 20:10:02 UTC
# 2  2014-12-12 20:10:02 UTC
# 3  2014-12-12 21:27:05 UTC
# 4  2014-12-12 21:27:05 UTC

# %% [markdown]
# In this dataset, only the position name will be taken.

# %%
# Taking only Position
experience = experience[['Applicant.ID', 'Position.Name']]

# Cleaning the text
experience['Position.Name'] = experience['Position.Name'].map(str).apply(clean_txt)
experience.head()
# Out:
#    Applicant.ID                                      Position.Name
# 0         10001  account manager sales administration quality a...
# 1         10001      electronics technician item master controller
# 2         10001                                   machine operator
# 3         10003                             maintenance technician
# 4         10003                                  electrical helper

# %%
experience =  experience.sort_values(by = 'Applicant.ID')
experience = experience.fillna(" ")
experience.head(10)
# Out:
#       Applicant.ID                                    Position.Name
# 2763             2                                        volunteer
# 2762             2                                writer uloop blog
# 3759             3                                    market intern
# 3758             3                                           server
# 3757             3                                        prep cook
# 6277             6                                project assistant
# 7490             8  deli clerk server cashier food prep order taker
# 368             11                                          cashier
# 809             12                                           server
# 810             12                                       rec leader

# %% [markdown]
# One applicant has three positions. I shall merge these positions.

# %%
#adding same rows to a single row
experience = experience.groupby('Applicant.ID', sort = False)['Position.Name'].apply(' '.join).reset_index()
experience.tail(10)
# Out:
#       Applicant.ID                                      Position.Name
# 3780         14626  fsr associate multifamily mortgage business as...
# 3781         14627                                               cook
# 3782         14630  product strategist product developer webdesign...
# 3783         14633  lead fraud analyst account manager development...
# 3784         14635                       lpn lpn cashier coffee maker
# 3785         14637                                                nan
# 3786         14638  doorman bartender facilities department bartender
# 3787         14639  senate intern student assistant property manag...
# 3788         14642  program manager business industry train divisi...
# 3789         14643  inflight wifi market tech support manager foun...

# %% [markdown]
# #### **Cleaning Positions of Interest data**

# %%
pos_int_df = pos_int.sort_values(by = 'Applicant.ID')
pos_int_df.head()
# Out:
#       Applicant.ID Position.Of.Interest               Created.At  \
# 6437            96               Server  2014-08-14 15:56:42 UTC
# 1156           153              Barista  2014-08-14 15:56:43 UTC
# 1155           153                 Host  2014-08-14 15:56:42 UTC
# 1154           153               Server  2014-08-14 15:56:42 UTC
# 1158           153            Sales Rep  2014-08-14 15:56:47 UTC
#
#                    Updated.At
# 6437  2015-02-26 20:35:12 UTC
# 1156  2015-02-18 02:35:06 UTC
# 1155  2015-02-26 20:35:12 UTC
# 1154  2015-02-26 20:35:12 UTC
# 1158  2015-03-02 02:13:08 UTC

# %%
pos_int_df = pos_int_df.drop(columns = ['Created.At', 'Updated.At'], axis = 1)

# Cleaning the text
pos_int_df['Position.Of.Interest'] = pos_int_df['Position.Of.Interest'].map(str).apply(clean_txt)
pos_int_df = pos_int_df.fillna(" ")
pos_int_df.head(10)
# Out:
#       Applicant.ID  Position.Of.Interest
# 6437            96                server
# 1156           153               barista
# 1155           153                  host
# 1154           153                server
# 1158           153             sales rep
# 1157           153  customer service rep
# 1952           256                  host
# 1957           256       production area
# 1956           256             sales rep
# 1955           256  customer service rep

# %%
pos_int_df = pos_int_df.groupby('Applicant.ID', sort = True)['Position.Of.Interest'].apply(' '.join).reset_index()
pos_int_df.head()
# Out:
#    Applicant.ID                               Position.Of.Interest
# 0            96                                             server
# 1           153  barista host server sales rep customer service...
# 2           256  host production area sales rep customer servic...
# 3           438           customer service rep barista host server
# 4           568      receptionist customer service rep book keeper

# %% [markdown]
# ##### **Creating the final user dataset by merging the Job views, Experience and Positions of Interest**

# %%
jobs_exp_df = job_view_df.merge(experience, left_on = 'Applicant.ID', right_on = 'Applicant.ID', how = 'outer')
jobs_exp_df = jobs_exp_df.fillna(' ')
jobs_exp_df = jobs_exp_df.sort_values(by = 'Applicant.ID')
jobs_exp_df.head()
# Out:
#        Applicant.ID job_view_text  \
# 12370             2
# 12371             3
# 12372             6
# 12373             8
# 12374            11
#
#                                          Position.Name
# 12370                      volunteer writer uloop blog
# 12371                   market intern server prep cook
# 12372                                project assistant
# 12373  deli clerk server cashier food prep order taker
# 12374                                          cashier

# %%
jobs_exp_pos_df = jobs_exp_df.merge(pos_int_df, left_on = 'Applicant.ID', right_on = 'Applicant.ID', how = 'outer')
jobs_exp_pos_df = jobs_exp_pos_df.fillna(' ')
jobs_exp_pos_df = jobs_exp_pos_df.sort_values(by = 'Applicant.ID')
jobs_exp_pos_df.head()
# Out:
#    Applicant.ID job_view_text  \
# 0             2
# 1             3
# 2             6
# 3             8
# 4            11
#
#                                      Position.Name Position.Of.Interest
# 0                      volunteer writer uloop blog
# 1                   market intern server prep cook
# 2                                project assistant
# 3  deli clerk server cashier food prep order taker
# 4                                          cashier

# %%
jobs_exp_pos_df['Text'] = jobs_exp_pos_df['job_view_text'].map(str) + jobs_exp_pos_df['Position.Name'] + " " + jobs_exp_pos_df['Position.Of.Interest']
jobs_exp_pos_df.head()
# Out:
#    Applicant.ID job_view_text  \
# 0             2
# 1             3
# 2             6
# 3             8
# 4            11
#
#                                      Position.Name Position.Of.Interest  \
# 0                      volunteer writer uloop blog
# 1                   market intern server prep cook
# 2                                project assistant
# 3  deli clerk server cashier food prep order taker
# 4                                          cashier
#
#                                                 Text
# 0                      volunteer writer uloop blog
# 1                   market intern server prep cook
# 2                                project assistant
# 3   deli clerk server cashier food prep order tak...
# 4                                          cashier

# %%
user_final_df = jobs_exp_pos_df[['Applicant.ID', 'Text']]
user_final_df.head()
# Out:
#    Applicant.ID                                               Text
# 0             2                      volunteer writer uloop blog
# 1             3                   market intern server prep cook
# 2             6                                project assistant
# 3             8   deli clerk server cashier food prep order tak...
# 4            11                                          cashier

# %%
user_final_df['Text'] = user_final_df['Text'].apply(clean_txt)
user_final_df.head()
# Out:
# <ipython-input-46-5b0b82f387b1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_final_df['Text'] = user_final_df['Text'].apply(clean_txt)
#    Applicant.ID                                             Text
# 0             2                      volunteer writer uloop blog
# 1             3                   market intern server prep cook
# 2             6                                project assistant
# 3             8  deli clerk server cashier food prep order taker
# 4            11                                          cashier

# %%
user1 = 210
index1 = np.where(user_final_df['Applicant.ID'] == user1)[0][0]
user_seghe = user_final_df.iloc[[index1]]
user_seghe
# Out:
#      Applicant.ID                  Text
# 137           210  laboratory assistant

# %%
user2 = 719
index2 = np.where(user_final_df['Applicant.ID'] == user2)[0][0]
user_gbade = user_final_df.iloc[[index2]]
user_gbade
# Out:
#      Applicant.ID      Text
# 372           719  chaplain

# %% [markdown]
# #### **Building the Recommender Systems**

# %% [markdown]
# ##### **Computing the Cosine Similarity using TF-IDF**

# %%
user_tfidf_seghe = tfidf_vect.transform(user_seghe['Text'])
cos_sim_tfidf_seghe = map(lambda x: cosine_similarity(user_tfidf_seghe, x), tfidf_comb)

# %%
user_tfidf_gbade = tfidf_vect.transform(user_gbade['Text'])
cos_sim_tfidf_gbade = map(lambda x: cosine_similarity(user_tfidf_gbade, x), tfidf_comb)

# %%
rec1 = list(cos_sim_tfidf_seghe)
rec2 = list(cos_sim_tfidf_gbade)

# %% [markdown]
# ##### **Computing the Top-N Recommendation by score**

# %%
def get_recommendation(top, comb_jobs_all, scores):
  recommendation = pd.DataFrame(columns = ['Applicant_ID', 'Job_ID',  'Title', 'Score'])
  count = 0
  for i in top:
      recommendation.at[count, 'Applicant_ID'] = user1
      recommendation.at[count, 'Job_ID'] = comb_jobs_all['Job.ID'][i]
      recommendation.at[count, 'Title'] = comb_jobs_all['Title'][i]
      recommendation.at[count, 'Score'] =  scores[count]
      count += 1
  return recommendation

# %% [markdown]
# ##### **Top Recommendations with TF-IDF**

# %%
top10_seghe_tfidf = sorted(range(len(rec1)), key = lambda i: rec1[i], reverse = True)[:10]
list_scores_seghe_tfidf = [rec1[i][0][0] for i in top10_seghe_tfidf]
get_recommendation(top10_seghe_tfidf, comb_jobs_all, list_scores_seghe_tfidf)
# Out:
#   Applicant_ID  Job_ID                                              Title  \
# 0          210  280951  Laboratory Technical Assistant (FTE .5 / Varia...
# 1          210  281502  Laboratory Technical Assistant (FTE .5 / Varia...
# 2          210  148551  TEMP - Laboratory Technician  - Nashville @ TE...
# 3          210  280684  Processing Laboratory : Laboratory Technician ...
# 4          210  246802  Medical Lab Scientist or Medical Lab Tech @ St...
# 5          210  264903  Laboratory Assistant (Temporary)- Lab @ Rockwo...
# 6          210  280915     Medical Laboratory Technician @ Swedish Health
# 7          210  281267     Medical Laboratory Technician @ Swedish Health
# 8          210  280873             Laboratory Technician @ Swedish Health
# 9          210  250257  LABORATORY TECHNICIAN @ Michigan Surgical Hosp...
#
#       Score
# 0  0.617245
# 1  0.596419
# 2  0.565705
# 3  0.543205
# 4   0.54182
# 5  0.523427
# 6  0.519801
# 7  0.508601
# 8  0.505145
# 9  0.503989

# %%
top10_gbade_tfidf = sorted(range(len(rec2)), key = lambda i: rec2[i], reverse = True)[:10]
list_scores_gbade_tfidf = [rec2[i][0][0] for i in top10_gbade_tfidf]
get_recommendation(top10_gbade_tfidf, comb_jobs_all, list_scores_gbade_tfidf)
# Out:
#   Applicant_ID  Job_ID                                              Title  \
# 0          210  265426      Part-Time Chaplain @ Tyson Foods Incorporated
# 1          210  244551      Part-Time Chaplain @ Tyson Foods Incorporated
# 2          210  172882      Part-Time Chaplain @ Tyson Foods Incorporated
# 3          210  250395      Part-Time Chaplain @ Tyson Foods Incorporated
# 4          210  252026      Part-Time Chaplain @ Tyson Foods Incorporated
# 5          210  276623      Part-Time Chaplain @ Tyson Foods Incorporated
# 6          210  313190      Part-Time Chaplain @ Tyson Foods Incorporated
# 7          210  263828   Chaplain On Call - California @ VITAS Healthcare
# 8          210  148052  Chaplain @ The Evangelical Lutheran Good Samar...
# 9          210  279991             Chaplain @ Catholic Health Initiatives
#
#       Score
# 0  0.753448
# 1  0.735256
# 2  0.730662
# 3  0.730622
# 4  0.729452
# 5  0.710595
# 6  0.704596
# 7  0.701806
# 8  0.677102
# 9  0.665359

# %%
count_vect = CountVectorizer()

# Fitting and transforming the vectorizer
count_comb = count_vect.fit_transform((comb_jobs_all['Text'])) #fitting and transforming the vector
count_comb
# Out:
# <84090x50753 sparse matrix of type '<class 'numpy.int64'>'
# 	with 8264225 stored elements in Compressed Sparse Row format>

# %%
user_count_seghe = count_vect.transform(user_seghe['Text'])
cos_sim_count_seghe = map(lambda x: cosine_similarity(user_count_seghe, x), count_comb)

# %%
user_count_gbade = count_vect.transform(user_gbade['Text'])
cos_sim_count_gbade = map(lambda x: cosine_similarity(user_count_gbade, x), count_comb)

# %%
rem1 = list(cos_sim_count_seghe)
rem2 = list(cos_sim_count_gbade)

# %% [markdown]
# ##### **Top Recommendations with Count Vectorizer**

# %%
top10_seghe_count = sorted(range(len(rem1)), key = lambda i: rem1[i], reverse = True)[:10]
list_scores_seghe_count = [rem1[i][0][0] for i in top10_seghe_count]
get_recommendation(top10_seghe_count, comb_jobs_all, list_scores_seghe_count)
# Out:
#   Applicant_ID  Job_ID                                              Title  \
# 0          210  280872  Laboratory Assistant II/Medical Assistant II @...
# 1          210  280745  Laboratory Assistant II/Medical Assistant II @...
# 2          210  284310  Laboratory Assistant II/Medical Assistant II @...
# 3          210  281448  Laboratory Assistant II/Medical Assistant II @...
# 4          210  280951  Laboratory Technical Assistant (FTE .5 / Varia...
# 5          210  281502  Laboratory Technical Assistant (FTE .5 / Varia...
# 6          210  264903  Laboratory Assistant (Temporary)- Lab @ Rockwo...
# 7          210  286414            Lab Assistant @ Main Line Health System
# 8          210  286392            Lab Assistant @ Main Line Health System
# 9          210  255430  Clinical Assistant / Lab Services Assistant @ ...
#
#       Score
# 0  0.624038
# 1  0.609557
# 2  0.601338
# 3  0.588348
# 4   0.57735
# 5  0.548821
# 6  0.514496
# 7   0.47194
# 8  0.463586
# 9  0.459573

# %%
top10_gbade_count = sorted(range(len(rem2)), key = lambda i: rem2[i], reverse = True)[:10]
list_scores_gbade_count = [rem2[i][0][0] for i in top10_gbade_count]
get_recommendation(top10_gbade_count, comb_jobs_all, list_scores_gbade_count)
# Out:
#   Applicant_ID  Job_ID                                              Title  \
# 0          210  265426      Part-Time Chaplain @ Tyson Foods Incorporated
# 1          210  172882      Part-Time Chaplain @ Tyson Foods Incorporated
# 2          210  250395      Part-Time Chaplain @ Tyson Foods Incorporated
# 3          210  252026      Part-Time Chaplain @ Tyson Foods Incorporated
# 4          210  276623      Part-Time Chaplain @ Tyson Foods Incorporated
# 5          210  313190      Part-Time Chaplain @ Tyson Foods Incorporated
# 6          210  263828   Chaplain On Call - California @ VITAS Healthcare
# 7          210  244551      Part-Time Chaplain @ Tyson Foods Incorporated
# 8          210  313189      Part-Time Chaplain @ Tyson Foods Incorporated
# 9          210  148052  Chaplain @ The Evangelical Lutheran Good Samar...
#
#       Score
# 0  0.576782
# 1  0.555294
# 2  0.555294
# 3  0.555294
# 4  0.532952
# 5  0.531085
# 6  0.524222
# 7  0.520579
# 8  0.501886
# 9  0.472456

# %% [markdown]
# #### **Recommendations Using KNN**

# %%
n_neighbors = 11
KNN = NearestNeighbors( p = 2)
KNN.fit(tfidf_comb)
knn_seghe = KNN.kneighbors(user_tfidf_seghe, return_distance = True)
knn_gbade = KNN.kneighbors(user_tfidf_gbade, return_distance = True)

# %%
knn_seghe[0][0][1:]
# Out:
# array([0.89842229, 0.93198201, 0.95581926, 0.95726741])

# %%
knn_gbade[0][0][1:]
# Out:
# array([0.72765877, 0.73394482, 0.73399983, 0.73559282])

# %% [markdown]
# ##### **Top Recommendations using KNN**

# %%
top10_seghe_knn = knn_seghe[1][0][1:]
index_score_seghe = knn_seghe[0][0][1:]

get_recommendation(top10_seghe_knn, comb_jobs_all, index_score_seghe)
# Out:
#   Applicant_ID  Job_ID                                              Title  \
# 0          210  281502  Laboratory Technical Assistant (FTE .5 / Varia...
# 1          210  148551  TEMP - Laboratory Technician  - Nashville @ TE...
# 2          210  280684  Processing Laboratory : Laboratory Technician ...
# 3          210  246802  Medical Lab Scientist or Medical Lab Tech @ St...
#
#       Score
# 0  0.898422
# 1  0.931982
# 2  0.955819
# 3  0.957267

# %%
top10_gbade_knn = knn_gbade[1][0][1:]
index_score_gbade = knn_gbade[0][0][1:]

get_recommendation(top10_gbade_knn, comb_jobs_all, index_score_gbade)
# Out:
#   Applicant_ID  Job_ID                                          Title  \
# 0          210  244551  Part-Time Chaplain @ Tyson Foods Incorporated
# 1          210  172882  Part-Time Chaplain @ Tyson Foods Incorporated
# 2          210  250395  Part-Time Chaplain @ Tyson Foods Incorporated
# 3          210  252026  Part-Time Chaplain @ Tyson Foods Incorporated
#
#       Score
# 0  0.727659
# 1  0.733945
# 2     0.734
# 3  0.735593
